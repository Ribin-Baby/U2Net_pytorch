.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_772ba96f.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_01b4c4ae.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_773ed527.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c3b49327.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_83b683a2.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_ab8129e0.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_d8bc9e2b.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_e703ff36.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8df8d0d7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_fbae74cf.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_21254839.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_eebb1088.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_e6d005d0.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_64da52e3.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_dfd1e18f.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8661f422.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_7dfc4104.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_9ed69917.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f8ce6700.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a027b8a1.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a3fdb557.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_930f61e7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a16e9e66.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_347de0d7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_dd3fab08.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_623491ca.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8d04d99a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_3076376f.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_9197d1f6.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_db03b516.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_0af8e77e.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a09f6d7a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_e228541a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_70f8cd6a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f05f1874.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_97a13c76.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c984713d.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_22bb8ec2.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_186ef845.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_d97027f4.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_10e752d1.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8b8eed77.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_1dfee663.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_117df2f2.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f560c3ee.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8b4dec90.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_be8e8817.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_88d2e15b.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_4559ef06.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_12aa0ad4.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_88769426.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_22105fbb.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_dc4c831e.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c7664967.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_27b0305c.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_bfe420db.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_26089b9d.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_2d8d5fd8.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_79667a8b.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f464b498.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_8776f290.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_50492861.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_48f2de97.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_7586d14a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_d482754b.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_d139f538.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_dcdc1e0a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_b1382594.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_4f573a53.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a283d89c.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_526030e3.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_2dac7786.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_6abcb4ed.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_cbc02a43.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_73e594c5.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_06f9fcb1.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_60dfee14.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_7e060171.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_61eec36a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_163ba3d7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_1e21958a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_9209383e.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f2af9c55.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c3ee0a89.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_6aaed593.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_4173e997.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_bf2fdaa1.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_ac499c80.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_0eabf5cb.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_fe54c949.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_74926d66.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_67ba476a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_244157c7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_ead6e9a3.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_0167e97d.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_d2cbcaaf.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_be75a9b3.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_682c8aab.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f8003d3c.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c39cb2f3.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_04c3542e.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_1825ac2b.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_6c14a1ab.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_01653554.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_cd80256d.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_c89f023a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_0ebda07a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_cca19cb7.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_3a6ec376.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_a22ecda6.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_ffdac4ba.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f049e784.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_99d2a3b9.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_2fd0b3e6.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_6517ab3a.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_f6595a2e.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_1ba36197.png
#   inflating: /content/sample_data/P3M-10k/validation/P3M-500-NP/trimap/p_ba8de511.png
#   inflating: /content/sample_data/P3M-10k/LICENSE
#   inflating: /content/sample_data/P3M-10k/readme.txt
#   inflating: /content/sample_data/P3M-10k/train_list.txt
#   inflating: /content/sample_data/P3M-10k/P3M-10k_Release_Agreement.pdf
#   inflating: /content/sample_data/P3M-10k/P3M-500-P_list.txt
#   inflating: /content/sample_data/P3M-10k/P3M-500-NP_list.txt

# %% [markdown]
# # import libraries

# %%
import os
from glob import glob
import sys
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from PIL.Image import Image as PILImage
from typing import Dict, List, Tuple
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import Dataset, DataLoader
import torch.optim.lr_scheduler as lr_scheduler

import u2net # upload from local drive [NOT FROM PIP]

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
HOME_PATH = "/content/sample_data/P3M-10k/"
TRAIN_PATH = os.path.join(HOME_PATH, "train")
TEST_PATH = os.path.join(HOME_PATH, "validation", "P3M-500-NP")

model_dir = "/content/sample_data/model_checkpoint"
if not os.path.exists(model_dir):
  os.mkdir(model_dir)
  os.mkdir(os.path.join(model_dir, "images"))

# hyperparameters
EPOCHS = 20
TRAIN_BATCH_SIZE = 10
VAL_BATCH_SIZE = 3
RESIZE = (320, 320)
lr = 2e-04

# %%
train_image_names = pd.read_csv("/content/sample_data/P3M-10k/train_list.txt", header=None)
train_image_names = train_image_names.values.flatten().tolist()

val_image_names = pd.read_csv("/content/sample_data/P3M-10k/P3M-500-NP_list.txt", header=None)
val_image_names = val_image_names.values.flatten().tolist()

# %%
# Define a custom transformation to normalize the mask
class NormalizeImage:
    def __call__(self, mask):
        # Ensure the mask values are between 0 and 1
        mask = torch.clamp(mask, 0, 1)
        return mask

class P3MDataset(Dataset):
    def __init__(self, root_dir, image_dir, mask_dir, image_names=[], resize=(224, 224)) -> None:
        super(P3MDataset, self).__init__()
        self.root_dir = root_dir
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_names = image_names

        # Add a transform to resize the images to 224x224.
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize(resize, antialias=True),
            NormalizeImage()
        ])

    def __len__(self):
      return len(os.listdir(os.path.join(self.root_dir, self.image_dir)))

    def __getitem__(self, index):
        name = self.image_names[index]
        # Load the image and mask at the given index.
        image = Image.open(os.path.join(self.root_dir, self.image_dir, f'{name}.jpg'))
        mask = Image.open(os.path.join(self.root_dir, self.mask_dir, f'{name}.png')).convert("L")
        # Apply the transform to the image.
        image = self.transform(image)
        mask = self.transform(mask)

        # Return the image and mask tensors.
        return image, mask

# %%
# Create the training dataset
train_dataset = P3MDataset(TRAIN_PATH, 'blurred_image', 'mask', train_image_names, resize=RESIZE)

# Create the validation dataset
val_dataset = P3MDataset(TEST_PATH, 'original_image', 'mask', val_image_names, resize=RESIZE)

# Create the training dataloader
train_dataloader = DataLoader(train_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True)

# Create the validation dataloader
val_dataloader = DataLoader(val_dataset, batch_size=VAL_BATCH_SIZE, shuffle=False)

# %%
# taking a batch for testing
data_iterator = iter(val_dataloader)  # Create an iterator from the DataLoader
val_batch = next(data_iterator)  # Load the next batch
len(val_batch), val_batch[0].shape
# Out:
# (2, torch.Size([3, 3, 320, 320]))

# %%
for imgs, masks in train_dataloader:
  imgs = imgs
  masks = masks
  print(imgs.shape, masks.shape)
  break
# Out:
# torch.Size([10, 3, 320, 320]) torch.Size([10, 1, 320, 320])

# %%
# load model
net = u2net.U2NET(3, 1)
if device == 'cuda':
  net.to(device)

logs = "/content/sample_data/logs"
writer = SummaryWriter(logs)

# %%
bce_loss = nn.BCELoss(reduction='mean')
net_optimizer = optim.Adam(net.parameters(), lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)
lmbda = lambda epoch: 0.65 ** epoch
scheduler = lr_scheduler.MultiplicativeLR(net_optimizer, lr_lambda=lmbda)

# loss function
def multi_BCEloss(s0, s1, s2, s3, s4, s5, s6, actual_mask):
  loss0 = bce_loss(s0, actual_mask)
  loss1 = bce_loss(s1, actual_mask)
  loss2 = bce_loss(s2, actual_mask)
  loss3 = bce_loss(s3, actual_mask)
  loss4 = bce_loss(s4, actual_mask)
  loss5 = bce_loss(s5, actual_mask)
  loss6 = bce_loss(s6, actual_mask)

  loss = loss0 + loss1 + loss2 + loss3 + loss4 + loss5 + loss6
  return loss0, loss

# %%
# training
epochs = EPOCHS
checkpoint_interval = 10
batch_interval = 150

net.train()
for epoch in range(0, epochs):
  for batch_id, (img, mask) in enumerate(train_dataloader):
    if device == 'cuda':
      img = img.to(device)
      mask = mask.to(device)
    s0, s1, s2, s3, s4, s5, s6 = net(img)
    loss0, loss = multi_BCEloss(s0, s1, s2, s3, s4, s5, s6, mask)
    net_optimizer.zero_grad()
    loss.backward()
    net_optimizer.step()

    # Print losses occasionally and print to tensorboard
    if batch_id % batch_interval == 0 :
        print(f"Epoch [{epoch}/{epochs}] Batch {batch_id}/{len(train_dataloader)} \
        Loss : {loss:.4f}, loss 0: {loss0:.4f}")
        with torch.no_grad():
          test_img, test_mask = val_batch
          if device == 'cuda':
             test_img = test_img.to(device)
             test_mask = test_mask.to(device)
          s0, s1, s2, s3, s4, s5, s6 = net(test_img)

          # Concatenate along the batch dimension
          combined = torch.cat((test_img, test_mask.repeat(1,3,1,1), s0.repeat(1,3,1,1)), dim=0)
          # Make a grid
          grid = torchvision.utils.make_grid(combined, nrow=3)
          # Convert tensor to numpy for visualization
          grid = grid.cpu().numpy().transpose((1, 2, 0))
          # Update the plot
          plt.ion()  # Turn on interactive mode
          fig, ax = plt.subplots()
          ax.clear()
          ax.set(xticks=[], yticks=[])
          ax.imshow(grid)
          plt.draw()
          plt.pause(0.001)  # Small pause to allow the plot to update
          fig.savefig(os.path.join(model_dir, 'images', 'image_at_epoch_{:02d}{:04d}.png'.format(epoch, batch_id)))

    # del temporary outputs and loss
    del s0, s1, s2, s3, s4, s5, s6, loss0
    # break
  scheduler.step()
  # Check if it's time to create a checkpoint
  # if epoch % checkpoint_interval == 0:
  #     checkpoint_filename = os.path.join(model_dir, f"model_checkpoint_epoch_{epoch + 1}.pt")
  #     checkpoint = {
  #           'epoch': epoch + 1,
  #           'batch': batch_id,
  #           'model_state_dict': net.state_dict(),
  #           'optimizer_state_dict': net_optimizer.state_dict(),
  #           'loss': loss,  # Save the current loss if needed
  #       # You can include more information in the checkpoint if necessary
  #       }
      # torch.save(checkpoint, checkpoint_filename)
    # break
  # break
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
checkpoint_filename = os.path.join(model_dir, f"u2net_model.pt")
checkpoint = {
      'epoch': epoch + 1,
      'batch': batch_id,
      'model_state_dict': net.state_dict(),
      'optimizer_state_dict': net_optimizer.state_dict(),
      'loss': loss,  # Save the current loss if needed
  # You can include more information in the checkpoint if necessary
  }
torch.save(checkpoint, checkpoint_filename)

# %%
# change mode to evaluation mode
net.eval()
mask_pred = net(imgs)
mask_pred[0].shape

plt.imshow(mask_pred[0][0].detach().cpu().repeat(3,1,1).permute(1,2,0))
plt.show()

# %%
# END
